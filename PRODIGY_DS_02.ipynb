# %% [markdown]
# PRODIGY_DS_02

# %%
import os
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("tested.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# THE AVERAGE NUMBER OF SURVIVED PASSENGERS

# %%
df['Survived']
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 413    0
# 414    1
# 415    0
# 416    0
# 417    0
# Name: Survived, Length: 418, dtype: int64

# %%
print("THE AVERAGE OF THE PASSEGERS SURVIVED ARE", float(str(sum(df['Survived'])/len(df['Survived']))[:4]))
#IN CODE TERMS
s = 0
for i in df["Survived"]:
    s += i
print("THE AVERAGE OF THE PASSEGERS SURVIVED ARE", float(str((s)/len(df['Survived']))[:4]))
# Out:
# THE AVERAGE OF THE PASSEGERS SURVIVED ARE 0.36
# THE AVERAGE OF THE PASSEGERS SURVIVED ARE 0.36

# %% [markdown]
# THE PERCENTAGE OF PASSENGERS SURVIVED

# %%
s = 0
for i in df['Survived']:
    s += i
print("THE PERCENTAGE OF SURVIVED PASSENGERS ARE", float(str((s)/len(df['Survived']))[:4])*100, "%")
# Out:
# THE PERCENTAGE OF SURVIVED PASSENGERS ARE 36.0 %

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.fillna(0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# NAME AND AGE OF PASSENGER WHO SURVIVED WHO ARE ABOVE 30

# %%
x = []
for i in range(len(df)):
    if df['Age'][i] >= 30.0 and df['Survived'][i] == 1:
        x.append((df['Name'][i], df['Age'][i]))
y = pd.DataFrame(x, columns=['NAME', 'AGE'], index = [np.arange(len(y))])
print(y)
# Out:
#                                                  NAME   AGE
# 0                    Wilkes, Mrs. James (Ellen Needs)  47.0
# 1                                Connolly, Miss. Kate  30.0
# 2   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  47.0
# 3               Assaf Khalil, Mrs. Mariana (Miriam")"  45.0
# 4     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  48.0
# 5            Dean, Mrs. Bertram (Eva Georgetta Light)  33.0
# 6               Corbett, Mrs. Walter H (Irene Colvin)  30.0
# 7    Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)  45.0
# 8     Bucknell, Mrs. William Robert (Emma Eliza Ward)  60.0
# 9      Coutts, Mrs. William (Winnie Minnie" Treanor)"  36.0
# 10                        Chaudanson, Miss. Victorine  36.0
# 11                Fortune, Mrs. Mark (Mary McDougald)  60.0
# 12                               Geiger, Miss. Amalie  35.0
# 13  Cornell, Mrs. Robert Clifford (Malvina Helen L...  55.0
# 14  Cavendish, Mrs. Tyrell William (Julia Florence...  76.0
# ...

# %% [markdown]
# PASSENGERS SURVIVED FROM CLASS 1

# %%
for i in range (len(df)):
    if df['Pclass'][i]== 1 and df['Survived'][i] == 1 :
        print(df['Name'][i])
# Out:
# Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# Chaffee, Mrs. Herbert Fuller (Carrie Constance Toogood)
# Flegenheim, Mrs. Alfred (Antoinette)
# Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# Ostby, Miss. Helene Ragnhild
# Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)
# Bucknell, Mrs. William Robert (Emma Eliza Ward)
# Fortune, Miss. Ethel Flora
# Chaudanson, Miss. Victorine
# Fortune, Mrs. Mark (Mary McDougald)
# Geiger, Miss. Amalie
# Cornell, Mrs. Robert Clifford (Malvina Helen Lamson)
# Davidson, Mrs. Thornton (Orian Hays)
# Cavendish, Mrs. Tyrell William (Julia Florence Siegel)
# Stengel, Mrs. Charles Emil Henry (Annie May Morris)
# Evans, Miss. Edith Corse
# Straus, Mrs. Isidor (Rosalie Ida Blun)
# Schabert, Mrs. Paul (Emma Mock)
# Daniels, Miss. Sarah
# Earnshaw, Mrs. Boulton (Olive Potter)
# Bird, Miss. Ellen
# Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genevieve Fosdick)
# Compton, Mrs. Alexander Taylor (Mary Eliza Ingersoll)
# ...

# %%
c=0
d=0
e=0
for i in df['Embarked']:
    if (i == 'S'):
        c +=1
    elif (i == 'Q'):
        d += 1
    elif (i == 'C'):
        e += 1
print('S =',c)
print('Q =',d)
print('C =',e)
# Out:
# S = 270
# Q = 46
# C = 102

# %%
sns.relplot(data=df, y="Age", x="Pclass", hue="Survived")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df, x="Sex", y="Survived", hue="Survived")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
sns.barplot(data=df, x="Ticket", y="Fare",hue ="Survived")
# Out:
# <Axes: xlabel='Ticket', ylabel='Fare'>

# %%
sns.histplot(data=df, x="Pclass", y="Embarked",hue ="Survived")
# Out:
# <Axes: xlabel='Pclass', ylabel='Embarked'>

# %% [markdown]
# THE ANALYSIS OF TITANIC DATA SET IS COMPLETED
